# %%
import pandas as pd


df_HDI = pd.read_csv('/Users/rinusvangrunsven/Documents/GitHub/FoDSD4/Data/Human Development Index (HDI).csv', sep=';').set_index('Country')
# df_HDI.set_index('Country')
cleaned = df_HDI.drop('HDI Rank', axis=1)
# # # df_HDI.groupby('Country')
display(cleaned)
# Out:
#                                                      1990   1991   1992  \
# Country
#  Afghanistan                                        0.302  0.307  0.316
#  Albania                                            0.650  0.631  0.615
#  Algeria                                            0.572  0.576  0.582
#  Andorra                                               ..     ..     ..
#  Angola                                                ..     ..     ..
# ...                                                   ...    ...    ...
# Sub-Saharan Africa                                  0.402  0.404  0.404
# Least Developed Countries                           0.350  0.353  0.354
# Small Island Developing States                      0.595  0.598  0.603
# Organization for Economic Co-operation and Deve...  0.785  0.790  0.788
# World                                               0.598  0.601  0.601
#
#                                                      1993   1994   1995  \
# Country
# ...

# %%
df_HI = pd.read_csv('/Users/rinusvangrunsven/Documents/GitHub/FoDSD4/Data/DataPanelWHR2021C2.csv', sep=';').set_index('Country name')
display(df_HI)
# Out:
#               year Life Ladder Log GDP per capita Social support  \
# Country name
# Afghanistan   2008       3,724              7,370          0,451
# Afghanistan   2009       4,402              7,540          0,552
# Afghanistan   2010       4,758              7,647          0,539
# Afghanistan   2011       3,832              7,620          0,521
# Afghanistan   2012       3,783              7,705          0,521
# ...            ...         ...                ...            ...
# Zimbabwe      2016       3,735              7,984          0,768
# Zimbabwe      2017       3,638              8,016          0,754
# Zimbabwe      2018       3,616              8,049          0,775
# Zimbabwe      2019       2,694              7,950          0,759
# Zimbabwe      2020       3,160              7,829          0,717
#
#              Healthy life expectancy at birth Freedom to make life choices  \
# Country name
# Afghanistan                            50,800                        0,718
# ...
